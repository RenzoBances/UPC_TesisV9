# %% [markdown]
# # Text into images

# %%
#!pip install Pillow
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

# %%
path = "images\\text\\push_up1_results.png"

# Open an Image
img = Image.open(path)
width, height = img.size
print(width, height)

I1 = ImageDraw.Draw(img)
font_h1 = ImageFont.truetype("C:\Windows\Fonts\cour.ttf", 32)
font_h2 = ImageFont.truetype("C:\Windows\Fonts\courbd.ttf", 24)
font_h3 = ImageFont.truetype("C:\Windows\Fonts\cour.ttf", 24)
#font = ImageFont.load_default()

I1.text((514, 50), ('RIGHT_HIT_ANGLE: {}'.format('165°')), fill =(0, 0, 0), font=font_h1)
I1.text((514, 90), ('Recomendación:'), fill =(0, 0, 0), font=font_h2)
I1.text((514, 110), ('Aumentar frecuencia de \nentrenamiento'), fill =(0, 0, 0), font=font_h3)

I1.text((56, 846), ('RIGHT_ELBOW_ANGLE: {}'.format('155°')), fill =(0, 0, 0), font=font_h1)
#I1.text((514, 90), ('Recomendación:'), fill =(0, 0, 0), font=font_h2)
#I1.text((514, 110), ('Aumentar frecuencia de \nentrenamiento'), fill =(0, 0, 0), font=font_h3)

I1.text((920, 826), ('RIGHT_KNEE_ANGLE: {}'.format('170°')), fill =(0, 0, 0), font=font_h1)

img
# Out:
# 1439 1080
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1439x1080>
